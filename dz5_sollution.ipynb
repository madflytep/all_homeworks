# %% [markdown]
# # Нахождение корней уравнения |sinx| = kx

# %% [markdown]
# Зададим функцию, соответствующую данному уравнению, а так же функции поиска корня делением отрезка пополам для возрастающих и убывающих участков

# %%
EPS = 10 ** (-8)

import math
import matplotlib
import matplotlib.pyplot as plt
import numpy

def f(x, k):
    return abs(math.sin(x)) - k * x

def left_sollution(f, a, b, k):
    while b - a > EPS:
        if f((a + b) / 2, k) <= 0:
            a = (a + b) / 2
        else:
            b = (a + b) / 2
    return a

def right_sollution(f, a, b, k):
    while b - a > EPS:
        if f((a + b) / 2, k) >= 0:
            a = (a + b) / 2
        else:
            b = (a + b) / 2
    return a

# %% [markdown]
# Найдем решения и обозначим их на графике для k = 0.1

# %%
k = 0.1
x_max = 1 / k
critical_number = int(x_max / math.pi + math.pi / 4)
results = []

for i in range(critical_number):
    results.append(left_sollution(f, i * math.pi, (i + 0.5) * math.pi, k))
    results.append(right_sollution(f, (i +0.5) * math.pi, (i + 1) * math.pi, k))

figure, regular_plot = plt.subplots()
x = numpy.arange(-0.5, x_max + 0.5, 0.01)
y1 = [abs(math.sin(a)) for a in x]
y2 = [k * a for a in x]
y_results = [k * a for a in results]
regular_plot.plot(x, y1)
regular_plot.plot(x, y2)
regular_plot.plot(results, y_results, 'o')
plt.show()
print(' '.join(map(str, results)))
# Out:
# 0.0 2.8523418928145805 3.4990638194472776 5.679207792886093 7.068174356758659 8.423203930516507

# %% [markdown]
# И для k = 0.01

# %%
EPS = 10 ** (-1)
k = 0.01
x_max = 1 / k
critical_number = int(x_max / math.pi + math.pi / 4)
results = []

for i in range(critical_number):
    results.append(left_sollution(f, i * math.pi, (i + 0.5) * math.pi, k))
    results.append(right_sollution(f, (i +0.5) * math.pi, (i + 1) * math.pi, k))

figure, regular_plot = plt.subplots()
x = numpy.arange(-0.5, x_max + 0.5, 0.01)
y1 = [abs(math.sin(a)) for a in x]
y2 = [k * a for a in x]
y_results = [k * a for a in results]
regular_plot.plot(x, y1)
regular_plot.plot(x, y2)
regular_plot.plot(results, y_results, 'o')
plt.show()
print(' '.join(map(str, results)))
# Out:
# 0.0 3.043417883165112 3.141592653589793 6.1850105367549055 6.283185307179586 9.326603190344699 9.42477796076938 12.370021073509811 12.664545384783853 15.511613727099604 15.806138038373646 18.653206380689397 18.94773069196344 21.696624263854506 22.187498115977917 24.838216917444303 25.329090769567706 27.979809571034092 28.470683423157503 31.02322745419921 31.710450847171977 34.164820107789 34.852043500761766 37.306412761378795 37.99363615435156 40.349830644543914 41.23340357836604 43.4914232981337 44.37499623195583 46.63301595172349 47.61476365597029 49.676433834888606 50.75635630956009 52.8180264884784 53.89794896314989 55.8614443716435 57.13771638716437 59.0030370252333 60.27930904075415 62.144629678823094 63.51907646476863 65.18804756198821 66.66066911835843 68.329640215578 69.80226177194821 71.37305809874312 73.0420291959627 74.51465075233291 76.18362184955248 77.55806863549802 79.42338927356695 80.69966128908781 82.56498192715675 83.74307917225292 85.80474935117122 86.88467182584272 89.0445167751857 89.92808970900782 92.1861094287755 92.97150759217294 95.42587685278997 96.01492547533806 98.76381904722913 99.05834335850317
